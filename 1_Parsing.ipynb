# %% [markdown]
# # Beautiful Soup

# %%
import urllib2
import csv
from bs4 import BeautifulSoup

# %%
#open url
data_source = 'https://finance.yahoo.com/'
req = urllib2.Request(data_source, headers={'User-Agent': 'Mozilla/5.0'})
page = urllib2.urlopen(req).read()
soup = BeautifulSoup(page, "html5lib")

# %% [markdown]
# ## Print html data

# %%
print type(soup)
print soup.prettify()
# Out:
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html class="NoJs featurephone" id="atomic" lang="en-US">
#  <head prefix="og: http://ogp.me/ns#">
#   <script>
#    window.performance && window.performance.mark && window.performance.mark('PageStart');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Yahoo Finance - Business Finance, Stock Market, Quotes, News
#   </title>
#   <meta content="401k, Business, Financial Information, Investing, Investor, Market News, Stock Research, Stock Valuation, business news, economy, finance, investment tools, mortgage, mutual funds, personal finance, quote, real estate, retirement, stock, stocks, Suze Orman, tax, track portfolio" name="keywords"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <meta content="on" property="twitter:dnt"/>
#   <meta content="90376669494" property="fb:app_id"/>
#   <meta content="#400090" name="theme-color"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="At Yahoo Finance, you get free stock quotes, up-to-date news, portfolio management resources, international market data, social interaction and mortgage rates that help you manage your financial life." lang="en-US" name="description"/>
#   <meta content="guce.yahoo.com" name="oath:guce:consent-host"/>
#   <meta content="A9862C0E6E1BE95BCE0BF3D0298FD58B" name="msvalidate.01"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="//l.yimg.com" rel="dns-prefetch"/>
#   <link href="//s.yimg.com" rel="dns-prefetch"/>
#   <link href="//csc.beap.bc.yahoo.com" rel="dns-prefetch"/>
#   <link href="//geo.query.yahoo.com" rel="dns-prefetch"/>
#   <link href="//y.analytics.yahoo.com" rel="dns-prefetch"/>
#   <link href="//b.scorecardresearch.com" rel="dns-prefetch"/>
#   <link href="//iquery.finance.yahoo.com" rel="dns-prefetch"/>
#   <link href="//fc.yahoo.com" rel="dns-prefetch"/>
#   <link href="//video-api.yql.yahoo.com" rel="dns-prefetch"/>
#   <link href="//yrtas.btrll.com" rel="dns-prefetch"/>
#   <link href="//shim.btrll.com" rel="dns-prefetch"/>
#   <link href="//consent.cmp.oath.com" rel="dns-prefetch"/>
#   <link href="//geo.yahoo.com" rel="dns-prefetch"/>
#   <link href="//l.yimg.com" rel="preconnect"/>
#   <link href="//s.yimg.com" rel="preconnect"/>
#   <link href="//csc.beap.bc.yahoo.com" rel="preconnect"/>
#   <link href="//geo.query.yahoo.com" rel="preconnect"/>
#   <link href="//y.analytics.yahoo.com" rel="preconnect"/>
#   <link href="//b.scorecardresearch.com" rel="preconnect"/>
#   <link href="//iquery.finance.yahoo.com" rel="preconnect"/>
#   <link href="//fc.yahoo.com" rel="preconnect"/>
#   <link href="//video-api.yql.yahoo.com" rel="preconnect"/>
#   <link href="//yrtas.btrll.com" rel="preconnect"/>
#   <link href="//shim.btrll.com" rel="preconnect"/>
#   <link href="//consent.cmp.oath.com" rel="preconnect"/>
#   <link href="//geo.yahoo.com" rel="preconnect"/>
#   <link href="https://s.yimg.com/os/mit/media/p/common/images/favicon_new-7483e38.svg" rel="icon" sizes="any"/>
#   <link href="https://finance.yahoo.com/favicon.ico" rel="alternate icon" type="image/x-icon"/>
#   <link href="https://finance.yahoo.com/" rel="canonical"/>
#   <link href="https://finance.yahoo.com" hreflang="x-default" rel="alternate"/>
#   <link href="https://ca.finance.yahoo.com" hreflang="en-CA" rel="alternate"/>
#   <link href="https://au.finance.yahoo.com" hreflang="en-AU" rel="alternate"/>
#   <link href="https://uk.finance.yahoo.com" hreflang="en-GB" rel="alternate"/>
#   <link href="https://in.finance.yahoo.com" hreflang="en-IN" rel="alternate"/>
#   <link href="https://sg.finance.yahoo.com" hreflang="en-SG" rel="alternate"/>
#   <link href="https://br.financas.yahoo.com" hreflang="pt-BR" rel="alternate"/>
#   <link href="https://finance.yahoo.com" hreflang="en-US" rel="alternate"/>
#   <meta content="@YahooFinance" property="twitter:site"/>
#   <meta content="90376669494" property="fb:pages"/>
#   <meta content="At Yahoo Finance, you get free stock quotes, up-to-date news, portfolio management resources, international market data, social interaction and mortgage rates that help you manage your financial life." property="og:description"/>
#   <meta content="Yahoo Finance - Business Finance, Stock Market, Quotes, News" property="og:title"/>
#   <meta content="At Yahoo Finance, you get free stock quotes, up-to-date news, portfolio management resources, international market data, social interaction and mortgage rates that help you manage your financial life." property="twitter:description"/>
#   <meta content="Yahoo Finance - Business Finance, Stock Market, Quotes, News" property="twitter:title"/>
#   <meta content="yfinance://" property="al:ios:url"/>
#   <meta content="328412701" property="al:ios:app_store_id"/>
#   <meta content="Yahoo Finance" property="al:ios:app_name"/>
#   <meta content="intent://#Intent;scheme=yfinance;action=android.intent.action.VIEW;package=com.yahoo.mobile.client.android.finance;S.browser_fallback_url=https%3A%2F%2Fplay.google.com%2Fstore%2Fapps%2Fdetails%3Fid%3Dcom.yahoo.mobile.client.android.finance;end" property="al:android:url"/>
#   <meta content="Yahoo Finance" property="al:android:app_name"/>
#   <meta content="com.yahoo.mobile.client.android.finance" property="al:android:package"/>
#   <meta content="app-id=328412701, affiliate-data=ct=us.fin.mbl.smart-banner&amp;pt=9029, app-argument=yfinance://" name="apple-itunes-app"/>
#   <link href="https://s.yimg.com/aaq/yc/css/bundle.ce149847.css" rel="stylesheet"/>
#   <link href="https://s.yimg.com/aaq/yc/css/patch.cd698090.css" rel="stylesheet"/>
#   <link href="https://s.yimg.com/uc/finance/dd-site/css/atomic.9218286f.css" rel="stylesheet"/>
#   <link href="https://s.yimg.com/uc/finance/dd-site/css/app.2a3890ad.css" rel="stylesheet"/>
#   <script defer="" src="https://www.yahoo.com/polyfill.min.js?features=locale-data-en-us%2Cpromise%2Carray.isarray%2Carray.prototype.every%2Carray.prototype.foreach%2Carray.prototype.indexof%2Carray.prototype.map%2Cdate.now%2Cfunction.prototype.bind%2Cobject.keys%2Cstring.prototype.trim%2Cobject.defineproperty%2Cobject.defineproperties%2Cobject.create%2Cobject.freeze%2Carray.prototype.filter%2Carray.prototype.reduce%2Cobject.assign%2Crequestanimationframe%2Cintl&amp;version=2.1.23">
#   </script>
#   <script src="https://s.yimg.com/aaq/yc/2.9.0/en.js">
#   </script>
#   <script src="https://s.yimg.com/zz/combo?ss/rapid3.js">
#   </script>
#   <script defer="" src="https://yep.video.yahoo.com/oath/js/1/oath-player.js">
#   </script>
#   <script src="https://s.yimg.com/rq/darla/3-16-1/js/g-r-min.js">
#   </script>
#   <script>
#    (function(html){var c = html.className;c += " JsEnabled";c = c.replace("NoJs","");html.className = c;})(document.documentElement);
#   </script>
#   <script>
#    document.createElement("header");document.createElement("section");document.createElement("article");document.createElement("figure");document.createElement("nav");document.createElement("aside");document.createElement("footer");
#   </script>
#   <script>
#    (function () {
# if (!window.YAHOO || !window.YAHOO.i13n || !window.YAHOO.i13n.Rapid) { return; }
# var rapidConfig = {"async_all_clicks":true,"click_timeout":300,"client_only":1,"compr_type":"deflate","keys":{"ver":"ydotcom","navtype":"server","pt":"home","mrkt":"us","site":"finance","lang":"en-US","colo":"gq1","_yrid":"fi5a18lemdob7","_rid":"fi5a18lemdob7","abk":""},"pageview_on_init":true,"query_parameters":true,"test_id":"finance-US-en-US-def","tracked_mods_viewability":[],"track_right_click":true,"viewability":true,"dwell_on":true,"perf_navigationtime":2,"perf_resourcetime":1,"webworker_file":"/__rapidworker-1.2.js","spaceid":"980770472"};
# (function (){var val = "; " + document.cookie; var parts = val.split("; thamba="); if (parts.length === 2){var abk = parts.pop().split(";").shift(); abk && rapidConfig.keys && (rapidConfig.keys.abk = abk === "2"?"abp" : "other");}})();
# window.rapidInstance = new window.YAHOO.i13n.Rapid(rapidConfig);
# })();
#   </script>
#  </head>
#  <body>
#   <div id="app">
#    <div data-react-checksum="-1433496404" data-reactid="1" data-reactroot="">
#     <div data-reactid="2">
#      <div class="render-target-active render-target-default" data-reactid="3" id="render-target-default">
#       <div class="finance US en-US H(100%) uh-search-open_Ovy(h) uh-search-open_H(100vh)" data-reactid="4">
#        <div class="YDC-MainCanvas Bgc($bg-body) Mih(100%)" data-reactid="5" id="YDC-MainCanvas" style="padding-top:54px;margin-bottom:auto;">
#         <div class="YDC-UH lw-nav-open_D(n)" data-reactid="6" id="YDC-UH" style="height:54px;">
#          <div class="YDC-UH-Stack Z(10) End(0) Start(0) T(0) Pos(f) uh-search-open_Pos(a) uh-mobile-nav-open_D(n) lw-nav-open_D(n)" data-reactid="7" id="YDC-UH-Stack">
#           <div data-reactid="8" id="YDC-UH-Stack-Composite">
#            <div data-reactid="9">
#             <div data-locator="subtree-root" id="mrt-node-UH-0-UH">
#              <div data-react-checksum="-452123520" data-reactid="1" data-reactroot="" id="UH-0-UH-Proxy">
#               <div data-reactid="2">
#                <div data-reactid="3">
#                 <div class="C(#fff) Fz(13px) H(22px)" data-reactid="4" id="masterNav">
#                  <ul class="H(22px) Lh(1.7) M(0) NavLinks P(0) Whs(nw) Z(11) Bgc(#2d1152) Pos(a) Start(0) End(0)" data-reactid="5" id="eyebrow" role="navigation">
#                   <!-- react-empty: 6 -->
#                  </ul>
#                 </div>
#                 <div class="Miw(980px) UH Z(10) Py(14px) Pos(r)" data-name="tdv2-applet-uh" data-reactid="7" data-version="10.1.42" id="UH-0-UH-0-Header">
#                  <div data-reactid="8">
#                   <div class="Fl(start) Fz(0) M(0) P(0) ie-7_W(190px) Miw(190px) UHMR1D_Py(0)" data-reactid="9" style="background-color:transparent;">
#                    <div data-reactid="10">
#                     <style data-reactid="11">
#                      #UH-0-UH-0-Header #uh-logo {background-image: url(https://s.yimg.com/rz/d/yahoo_finance_en-US_s_f_pw_351x40_finance.png);} @media  only screen and ( -webkit-min-device-pixel-ratio: 2 ), only screen and ( min--moz-device-pixel-ratio: 2), only screen and ( -o-min-device-pixel-ratio: 2/1), only screen and ( min-device-pixel-ratio: 2), only screen and ( min-resolution: 192dpi), only screen and ( min-resolution: 2dppx), only screen and ( min-aspect-ratio: 2/1 ) { #UH-0-UH-0-Header #uh-logo {background-image: url(https://s.yimg.com/rz/d/yahoo_finance_en-US_s_f_pw_351x40_finance_2x.png);} }
#                     </style>
#                     <a class="Bgpx(0) Bgr(nr) Cur(p) D(b) H(35px) Bgz(702px) Mx(a)! W(92px)" data-reactid="12" href="https://finance.yahoo.com/" id="uh-logo">
#                      <b class="Hidden" data-reactid="13">
#                       Yahoo
#                      </b>
#                     </a>
#                    </div>
#                   </div>
#                   <div class="Bdrs(3px) D(b) Start(0) W(100%) Z(4)" data-reactid="14" id="uh-search">
#                    <form action="/quote/" class="M(0) P(0) Whs(nw)" data-reactid="15" method="get" name="input">
#                     <label class="Hidden" data-reactid="16" for="fin-srch-assist">
#                      Search
#                     </label>
#                     <div class="" data-reactid="17">
#                      <div class="Z(2) Pos(r) IbBox uh-search-open_W($srchInputTouchDeviceWidth) W(100%)" data-reactid="18" id="fin-srch-assist">
#                       <input aria-label="Search" autocapitalize="off" autocomplete="off" autocorrect="off" class="Pos(r) W(100%) H(35px) M(0) O(0) O(0):f Bgc(white) Z(2) Bxsh(n) Bxsh(n):f Pt(6px) Pb(8px) Pstart(36px) Pend(20px) Va(t) Bd(0) Bdrs(2px) Fz(16px)" data-reactid="19" id="yfin-usr-qry" maxlength="4096" name="yfin-usr-qry" placeholder="Search for news, symbols or companies" type="text" value=""/>
#                       <div class="Z(2) Pos(a) Start(8px) T(8px)" data-reactid="20">
#                        <svg class="H(20px) W(20px) Va(m)! Fill($finDarkGray)! Stk($finDarkGray) Cur(p)" data-icon="search" data-reactid="21" height="20" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewBox="0 0 24 24" width="20">
#                         <path d="M9 3C5.686 3 3 5.686 3 9c0 3.313 2.686 6 6 6s6-2.687 6-6c0-3.314-2.686-6-6-6m13.713 19.713c-.387.388-1.016.388-1.404 0l-7.404-7.404C12.55 16.364 10.85 17 9 17c-4.418 0-8-3.582-8-8 0-4.42 3.582-8 8-8s8 3.58 8 8c0 1.85-.634 3.55-1.69 4.905l7.403 7.404c.39.386.39 1.015 0 1.403" data-reactid="22">
#                         </path>
#                        </svg>
#                       </div>
#                       <div class="Pos(a) Z(2) End(0) T(0)" data-reactid="23">
#                       </div>
#                      </div>
#                      <script data-reactid="24">
#                       (function () {
#         var inputEl = document.getElementById('yfin-usr-qry');
#         var perf = window.performance;
#         if (inputEl && inputEl.addEventListener && perf && perf.mark && perf.getEntriesByName) {
#             var listener = function (e) {
#                 inputEl.removeEventListener('keyup', listener);
#                 if (perf.getEntriesByName('Fin.Search first keyup').length === 0) {
#                     perf.mark('Fin.Search first keyup');
#                 }
#             };
#             inputEl.addEventListener('keyup', listener);
#         }
#     })();
#                      </script>
#                      <div class="Pos(a) Ta(start) Start(0) End(0) Bgc(white) Z(1) Wob(ba) Whs(n) Bxsh($boxShadow) D(n) Mt(8px) Bd(0)" data-reactid="25" data-test="search-assist-input-sugglst">
#                       <div class="M(0) Pb(5px) Bxsh($boxShadow) Bdrsbend(3px) Bdrsbstart(3px) " data-reactid="26">
#                        <div class="Mb(10px) Pt(40px) Ta(c)" data-reactid="27">
#                         <svg class="H(20px) W(20px) Mend(10px) Va(m)! Fill($finDarkGray)! Stk($finDarkGray) Cur(a)! Cur(p)" data-icon="attention" data-reactid="28" height="20" style="fill:#000;stroke:#000;stroke-width:0;vertical-align:bottom;" viewBox="0 0 48 48" width="20">
#                          <path d="M24.993 46.424c-12.13 0-22-9.87-22-22s9.87-22 22-22 22 9.87 22 22-9.87 22-22 22zm0-40c-9.925 0-18 8.075-18 18 0 9.926 8.075 18 18 18s18-8.074 18-18c0-9.924-8.075-18-18-18zM24.993 27.424c-1.104 0-2-.895-2-2v-10c0-1.104.896-2 2-2s2 .896 2 2v10c0 1.105-.895 2-2 2zM22.993 33.424a2 2 0 1 0 4 0 2 2 0 1 0-4 0z" data-reactid="29">
#                          </path>
#                         </svg>
#                        </div>
#                        <div class="C($finDarkGray) Fw(500) Fz(m) Ta(c) Pb(40px) Px(20px)" data-reactid="30">
#                         <span data-reactid="31">
#                          No matching results for ''
#                         </span>
#                        </div>
#                       </div>
#                       <div class="Ta(start) C($finDarkGray) Fz(s) Fz(500) D(b) Py(8px) Pstart(20px)" data-reactid="32">
#                        <span data-reactid="33">
#                         Tip: Try a valid symbol or a specific company name for relevant results
#                        </span>
#                       </div>
#                       <div class="Ta(end) Bgc($extraLightGray)" data-reactid="34">
#                        <a class="C($c-fuji-grey-h) Fz(12px) Td(n) Td(u):h D(b) Py(8px) Pend(20px)" data-reactid="35" href="https://www.research.net/r/Desktopbucket" rel="noopener" target="_blank">
#                         <span data-reactid="36">
#                          Give feedback on the new search experience
#                         </span>
#                        </a>
#                       </div>
#                      </div>
#                      <button class="C(white) Bd(0) Fw(500) Fz(s) Px(10px) Py(5px) Ta(c) uh-search-open_D(ib) D(n) Va(m) H(35px) Fl(end)" data-reactid="37" type="button">
#                       <div class="Ell D(ib) Maw(80px)" data-reactid="38">
#                        <span data-reactid="39">
#                         Cancel
#                        </span>
#                       </div>
#                      </button>
#                     </div>
#                     <input data-reactid="40" name="fr" type="hidden" value="uh3_finance_vert"/>
#                     <input data-reactid="41" name="fr2" type="hidden" value="p:finvsrp,m:sb"/>
#                     <input data-reactid="42" name=".tsrc" type="hidden" value=""/>
#                    </form>
#                   </div>
#                   <ul class="End(20px) List(n) Pos(a) T(14px)" data-reactid="43" id="uh-right">
#                    <li class="Fl(start) Mx(4px) Mend(9px) V(h)" data-reactid="44">
#                     <svg class="Cur(p)" data-icon="profile" data-reactid="45" height="34" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewBox="0 0 48 48" width="34">
#                      <path d="M4.095 33.61c1.092 2.7 2.607 4.937 4.562 6.696 1.94 1.766 4.23 3.072 6.847 3.922 2.632.846 5.472 1.27 8.53 1.27 3.012 0 5.837-.425 8.458-1.27 1.053-.342 2.046-.754 2.986-1.244 1.41-.732 2.705-1.617 3.87-2.678 1.948-1.76 3.472-3.996 4.558-6.697 1.092-2.7 1.636-5.903 1.636-9.614 0-3.702-.544-6.904-1.636-9.61-1.086-2.703-2.608-4.934-4.56-6.694-1.944-1.767-4.23-3.07-6.854-3.922-2.62-.847-5.445-1.27-8.457-1.27-3.06 0-5.9.423-8.53 1.27-.847.277-1.662.607-2.443.98-1.623.777-3.1 1.753-4.404 2.942-1.956 1.76-3.47 3.992-4.562 6.694-1.09 2.706-1.636 5.908-1.636 9.61-.002 3.71.545 6.914 1.635 9.613zM35.838 34.758l-23.674.002v-2.21s.017-1.425 3.123-2.716c1.538-.633 3.35-1.854 6.6-2.24-.997-.705-1.44-2.154-2.29-4.17-.02-.032-.03-.068-.043-.1-.193.032-.393.032-.537-.046-.398-.232-.636-1.48-.642-2.092-.01-.906.48-.824.48-.824s.017 0 .042-.004c-.006-.07-.01-.142-.01-.213 0-.86-.174-2.24.053-2.988.353-1.176.78-2.46 1.72-2.464.874 0 .28-1.006 1.348-1.345 1.102-.348 2.912.262 3.283.262.53 0 1.863.378 2.78 1.284.646.64.572 1.08.93 2.25.23.777.057 2.167.057 3 0 .07-.007.14-.014.213.018.007.03.007.03.007s.487-.082.478.824c-.004.612-.248 1.86-.635 2.092-.146.078-.34.078-.53.052-.01.026-.023.058-.033.09-.85 1.996-1.308 3.457-2.305 4.162 3.283.38 5.107 1.61 6.654 2.25 3.128 1.287 3.14 2.533 3.14 2.533l-.002 2.39z" data-reactid="46">
#                      </path>
#                     </svg>
#                    </li>
#                    <li class="D(ib) Mstart(14px) Mt(-1px) ua-ie8_Pb(10px) ua-ie9_Pb(10px)" data-reactid="47">
#                     <a class="Pos(r) D(ib) Ta(s) Td(n):h" data-reactid="48" href="https://mail.yahoo.com/?.intl=us&amp;.lang=en-US&amp;.partner=none&amp;.src=finance" id="uh-mail">
#                      <svg class="Cur(p)" data-icon="NavMail" data-reactid="49" height="35" style="fill:#400090;stroke:#400090;stroke-width:0;vertical-align:bottom;" viewBox="0 0 512 512" width="30">
#                       <path d="M460.586 91.31H51.504c-10.738 0-19.46 8.72-19.46 19.477v40.088l224 104.03 224-104.03v-40.088c0-10.757-8.702-19.478-19.458-19.478M32.046 193.426V402.96c0 10.758 8.72 19.48 19.458 19.48h409.082c10.756 0 19.46-8.722 19.46-19.48V193.428l-224 102.327-224-102.327z" data-reactid="50">
#                       </path>
#                      </svg>
#                      <b class="Lh(userNavTextLh) D(ib) C($c-fuji-purple-1-c) Fz(14px) Fw(b) Va(t) Mstart(6px)" data-reactid="51">
#                       Mail
#                      </b>
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#             <script>
#              if (window.performance) {window.performance.mark && window.performance.mark('UH-0-UH');window.performance.measure && window.performance.measure('UH-0-UHDone','PageStart','UH-0-UH');}
#             </script>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="Bgc($bg-content) Pos(r) Z(1) uh-mobile-nav-open_D(n) lw-nav-open_D(n) lw-nav-open_Pos(a) lw-nav-open_T(54px)" data-reactid="10">
#          <!-- react-empty: 11 -->
#          <!-- react-empty: 12 -->
#          <div class="YDC-Col1" data-reactid="13" id="YDC-Col1">
#           <div class="YDC-Col1-Stack SideSlot-open_D(n)" data-reactid="14" id="YDC-Col1-Stack">
#            <div data-reactid="15" id="YDC-Col1-Stack-Composite">
#             <div data-reactid="16">
#              <div data-locator="subtree-root" id="mrt-node-Col1-0-MarketSummary">
#               <div data-react-checksum="498152039" data-reactid="1" data-reactroot="" id="Col1-0-MarketSummary-Proxy">
#                <div aria-label="Market summary containing a list of 15 items" class="Whs(nw) Bgc(white) My(20px) Bxz(bb) Ovy(h) Ovx(a)" data-reactid="2" id="market-summary" tabindex="0">
#                 <ul aria-label="Market summary containing a list of 15 items" class="Mstart(20px) W(100%)" data-reactid="3" id="market-summary" tabindex="0">
#                  <li aria-label="S&amp;P 500" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="4">
#                   <a aria-label="S&amp;P 500 has increased by 0.65% or 18.78 points to 2,887.94 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="5" href="/quote/^GSPC?p=^GSPC" title="S&amp;P 500">
#                    <!-- react-text: 6 -->
#                    S&amp;P 500
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="7">
#                     2,887.94
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="8">
#                     +0.65%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Dow 30" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="9">
#                   <a aria-label="Dow 30 has increased by 1.00% or 258.20 points to 26,036.10 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="10" href="/quote/^DJI?p=^DJI" title="Dow 30">
#                    <!-- react-text: 11 -->
#                    Dow 30
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="12">
#                     26,036.10
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="13">
#                     +1.00%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Nasdaq" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="14">
#                   <a aria-label="Nasdaq has increased by 0.38% or 29.94 points to 7,856.88 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="15" href="/quote/^IXIC?p=^IXIC" title="Nasdaq">
#                    <!-- react-text: 16 -->
#                    Nasdaq
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="17">
#                     7,856.88
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="18">
#                     +0.38%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Russell 2000" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="19">
#                   <a aria-label="Russell 2000 has increased by 1.14% or 16.66 points to 1,472.70 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="20" href="/quote/^RUT?p=^RUT" title="Russell 2000">
#                    <!-- react-text: 21 -->
#                    Russell 2000
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="22">
#                     1,472.70
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="23">
#                     +1.14%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Crude Oil" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="24">
#                   <a aria-label="Crude Oil has increased by 1.80% or 0.99 points to 55.92 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="25" href="/quote/CL=F?p=CL=F" title="Crude Oil">
#                    <!-- react-text: 26 -->
#                    Crude Oil
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="27">
#                     55.92
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="28">
#                     +1.80%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Gold" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataRed)" data-reactid="29">
#                   <a aria-label="Gold has decreased by -0.23% or -3.60 points to 1,548.20 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="30" href="/quote/GC=F?p=GC=F" title="Gold">
#                    <!-- react-text: 31 -->
#                    Gold
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="32">
#                     1,548.20
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataRed)" data-reactid="33">
#                     -0.23%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Silver" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="34">
#                   <a aria-label="Silver has increased by 0.86% or 0.16 points to 18.31 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="35" href="/quote/SI=F?p=SI=F" title="Silver">
#                    <!-- react-text: 36 -->
#                    Silver
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="37">
#                     18.31
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="38">
#                     +0.86%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="EUR/USD" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataRed)" data-reactid="39">
#                   <a aria-label="EUR/USD has decreased by -0.1330% or -0.0015 points to 1.1080 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="40" href="/quote/EURUSD=X?p=EURUSD=X" title="EUR/USD">
#                    <!-- react-text: 41 -->
#                    EUR/USD
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="42">
#                     1.1080
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataRed)" data-reactid="43">
#                     -0.1330%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="10-Yr Bond" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataRed)" data-reactid="44">
#                   <a aria-label="10-Yr Bond has decreased by -1.61% or -0.0240 points to 1.4660 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="45" href="/quote/^TNX?p=^TNX" title="10-Yr Bond">
#                    <!-- react-text: 46 -->
#                    10-Yr Bond
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="47">
#                     1.4660
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataRed)" data-reactid="48">
#                     -1.61%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Vix" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataRed)" data-reactid="49">
#                   <a aria-label="Vix has decreased by -5.07% or -1.03 points to 19.28 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="50" href="/quote/^VIX?p=^VIX" title="Vix">
#                    <!-- react-text: 51 -->
#                    Vix
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="52">
#                     19.28
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataRed)" data-reactid="53">
#                     -5.07%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="GBP/USD" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataRed)" data-reactid="54">
#                   <a aria-label="GBP/USD has decreased by -0.6180% or -0.0076 points to 1.2213 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="55" href="/quote/GBPUSD=X?p=GBPUSD=X" title="GBP/USD">
#                    <!-- react-text: 56 -->
#                    GBP/USD
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="57">
#                     1.2213
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataRed)" data-reactid="58">
#                     -0.6180%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="USD/JPY" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="59">
#                   <a aria-label="USD/JPY has increased by 0.3972% or 0.4200 points to 106.1700 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="60" href="/quote/JPY=X?p=JPY=X" title="USD/JPY">
#                    <!-- react-text: 61 -->
#                    USD/JPY
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="62">
#                     106.1700
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="63">
#                     +0.3972%
#                    </span>
#                   </a>
#                  </li>
#                  <li class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataRed)" data-reactid="64">
#                   <a aria-label=" has decreased by -4.86% or -494.37 points to 9,681.10 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="65" href="/quote/BTC-USD?p=BTC-USD" title="BTC-USD">
#                    <!-- react-text: 66 -->
#                    BTC-USD
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="67">
#                     9,681.10
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataRed)" data-reactid="68">
#                     -4.86%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="FTSE 100" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="69">
#                   <a aria-label="FTSE 100 has increased by 0.35% or 25.13 points to 7,114.71 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="70" href="/quote/^FTSE?p=^FTSE" title="FTSE 100">
#                    <!-- react-text: 71 -->
#                    FTSE 100
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="72">
#                     7,114.71
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="73">
#                     +0.35%
#                    </span>
#                   </a>
#                  </li>
#                  <li aria-label="Nikkei 225" class="Bxz(bb) D(ib) Whs(n) Bdstartw(4px) Bdstarts(s) Bdstartc($dataGreen)" data-reactid="74">
#                   <a aria-label="Nikkei 225 has increased by 0.11% or 23.34 points to 20,479.42 points" class="C(black) Fw(500) Fz(m) Td(n) Pend(34px) Pstart(10px) D(b)" data-reactid="75" href="/quote/^N225?p=^N225" title="Nikkei 225">
#                    <!-- react-text: 76 -->
#                    Nikkei 225
#                    <!-- /react-text -->
#                    <span class="Trsdu(0.3s) Fz(s) Mb(0px) D(b)" data-reactid="77">
#                     20,479.42
#                    </span>
#                    <span class="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)" data-reactid="78">
#                     +0.11%
#                    </span>
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#              <script>
#               if (window.performance) {window.performance.mark && window.performance.mark('Col1-0-MarketSummary');window.performance.measure && window.performance.measure('Col1-0-MarketSummaryDone','PageStart','Col1-0-MarketSummary');}
#              </script>
#             </div>
#             <div data-reactid="17">
#              <div data-locator="subtree-root" id="mrt-node-Col1-1-Empty">
#               <div data-react-checksum="-1859576442" data-reactid="1" data-reactroot="" id="Col1-1-Empty-Proxy">
#                <!-- react-empty: 2 -->
#               </div>
#              </div>
#              <script>
#               if (window.performance) {window.performance.mark && window.performance.mark('Col1-1-Empty');window.performance.measure && window.performance.measure('Col1-1-EmptyDone','PageStart','Col1-1-Empty');}
#              </script>
#             </div>
#             <div data-reactid="18">
#              <div data-locator="subtree-root" id="mrt-node-slingstoneStream-0-Stream">
#               <div data-react-checksum="1875477472" data-reactid="1" data-reactroot="" id="slingstoneStream-0-Stream-Proxy">
#                <div class="tdv2-applet-stream Bdc(#e2e2e6)" data-reactid="2" id="slingstoneStream-0-Stream" style="max-width:900px;">
#                 <ul class="My(0) Ov(h) P(0) Wow(bw)" data-reactid="3">
#                  <li class="js-stream-content" data-reactid="4">
#                   <div class="W(100%) Maw(900px) Mb(15px)" data-reactid="5" data-test-locator="streamhero" id="item-0">
#                    <div class="Pos(r) Cf Wow(bw)" data-reactid="6">
#                     <div class="Pos(r) streamHeroImage W(74.9%) W(66.6%)--md1100 Fl(start) Mend(2px)" data-reactid="7">
#                      <a class="Td(n)" data-reactid="8" href="/video/yahoo-finance-live-aug-28-134651257.html">
#                       <div class="Pos(r) C(#000) H(0) Ovy(h)" data-reactid="9" style="padding-bottom:56.3%;" tabindex="-1">
#                        <img alt="Yahoo Finance LIVE " class=" W(100%) Trs(streamHeroImgFilterTrans) streamHeroImage:h_Op(0.9) streamHeroImage:h_Fil(ntkImgFilterHover) Fil(streamHeroImgFilter)" data-reactid="10" src="https://s.yimg.com/uu/api/res/1.2/VM7qJzfyFaZprfpacHSCmA--~B/Zmk9c3RyaW07aD01MDU7cHlvZmY9MDtxPTk1O3c9OTAwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-03/46212d00-4653-11e9-bebe-329ac83811b0"/>
#                       </div>
#                      </a>
#                      <div class="Pos(a) B(0) Start(0) End(0) Bg(streamHeroLeadGradient) Pstart(18px)--md1100 Pt(50px) Pend(45px) Pend(25px)--md1100 Pstart(25px)" data-reactid="11">
#                       <div class="C(#fff) Mb(14px)" data-reactid="12">
#                        <a class="Fw(b) Td(n) C(#fff) C(#fff):h" data-reactid="13" href="/video/yahoo-finance-live-aug-28-134651257.html">
#                         <h2 class="Fz(22px)--md1100 Lh(25px)--md1100 Fw(700) Tsh(streamHeroTextShadow) Td(u):h Fz(25px) Lh(31px)" data-reactid="14">
#                          Yahoo Finance LIVE
#                         </h2>
#                         <p class="C($c-fuji-grey-a) Tov(e) firefox_D(b)! Tsh(streamHeroTextShadow) Fw(400) Pb(4px) Fz(14px) LineClamp(2,34px) Pt(6px)" data-reactid="15">
#                          <span class="Mend(5px)" data-reactid="16">
#                           Executives, experts and influencers join the Yahoo Finance team to discuss what's moving the world of finance.
#                          </span>
#                          <span class="D(ib) Td(u):h Fw(600) C(#fff)" data-reactid="17">
#                           <!-- react-text: 18 -->
#                           WATCH LIVE
#                           <!-- /react-text -->
#                           <!-- react-text: 19 -->
#                           »
#                           <!-- /react-text -->
#                          </span>
#                         </p>
#                        </a>
#                       </div>
#                       <div class="Mb(10px)" data-reactid="20" data-test-locator="streamhero-actions">
#                       </div>
#                      </div>
#                     </div>
#                     <div class="Ov(h) Mstart(74.9%) Mstart(66.67%)--md1100" data-reactid="21">
#                      <ul class="Pos(r) H(0) Pb(169.3%) Pb(113.6%)--md1100" data-reactid="22" style="top:0;transition:top .4s;">
#                       <li class="Pos(r) streamHeroImage Mb(2px) D(b)" data-reactid="23">
#                        <a class="ie-7_D(b)" data-reactid="24" href="/news/stock-market-news-august-28-2019-122927393.html">
#                         <div class="Pos(r) C(#000) H(0) Ovy(h) Pb(56.16%)" data-reactid="25" tabindex="-1">
#                          <img alt="Stocks jump as energy shares rise" class=" W(100%) Trs(streamHeroImgFilterTrans) streamHeroImage:h_Op(0.9) streamHeroImage:h_Fil(ntkImgFilterHover) Fil(streamHeroImgFilter)" data-reactid="26" src="https://s.yimg.com/uu/api/res/1.2/vX5kkEnKewbEIXYgbkQsHw--~B/Zmk9c3RyaW07aD0yMzI7cHlvZmY9MDtxPTgwO3c9NDEyO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-images/2019-08/24109870-c5e9-11e9-bafe-c2bc3a7ba829"/>
#                         </div>
#                         <div class="Pos(a) B(0) Start(0) End(0) Pt(20px) Bg(streamHeroGradient)" data-reactid="27">
#                          <h3 class="Td(n) C(#fff) Fz(13px) Td(u):h LineClamp(3,45px) Mend(30px) Mend(23px)--md1100 Mstart(12px) B(0) Fw(b) Mb(10px) Lh(15px) Tsh(streamHeroTextShadow) Whs(n)" data-reactid="28">
#                           Stocks jump as energy shares rise
#                          </h3>
#                         </div>
#                        </a>
#                       </li>
#                       <li class="Pos(r) streamHeroImage Mb(2px) D(b)" data-reactid="29">
#                        <a class="ie-7_D(b)" data-reactid="30" href="/news/for-first-time-since-trump-elected-more-voters-say-economy-is-worsening-183058325.html">
#                         <div class="Pos(r) C(#000) H(0) Ovy(h) Pb(56.16%)" data-reactid="31" tabindex="-1">
#                          <img alt="More voters say economy is worsening than improving" class=" W(100%) Trs(streamHeroImgFilterTrans) streamHeroImage:h_Op(0.9) streamHeroImage:h_Fil(ntkImgFilterHover) Fil(streamHeroImgFilter)" data-reactid="32" src="https://s.yimg.com/uu/api/res/1.2/HIOPCTbm6w_r_4hWpp_rzA--~B/Zmk9c3RyaW07aD0xMTY7cHlvZmY9MDtxPTk1O3c9MjA2O3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/lo/api/res/1.2/JIN_Sj7pZqq8T6RuOr_Z3g--~C/Y2g9MTk1NC4zMzMzMzMzMzMzMzMzO2NyPTE7Y3c9MzQ2OC4yNTM1MjExMjY3NjE7ZHg9Mjc2Ljg0NTA3MDQyMjUzNTIzO2R5PTE0Ni4zNzAzNzAzNzAzNzAzNTtmaT11bGNyb3A7O2FwcGlkPXByb2Rlc2sy/https://s.yimg.com/os/creatr-images/2019-08/82035da0-c823-11e9-bfbf-4c08065329b9"/>
#                         </div>
#                         <div class="Pos(a) B(0) Start(0) End(0) Pt(20px) Bg(streamHeroGradient)" data-reactid="33">
#                          <h3 class="Td(n) C(#fff) Fz(13px) Td(u):h LineClamp(3,45px) Mend(30px) Mend(23px)--md1100 Mstart(12px) B(0) Fw(b) Mb(10px) Lh(15px) Tsh(streamHeroTextShadow) Whs(n)" data-reactid="34">
#                           More voters say economy is worsening than improving
#                          </h3>
#                         </div>
#                        </a>
#                       </li>
#                       <li class="Pos(r) streamHeroImage Mb(2px) D(b)" data-reactid="35">
#                        <a class="ie-7_D(b)" data-reactid="36" href="/news/apple-card-review-195106544.html">
#                         <div class="Pos(r) C(#000) H(0) Ovy(h) Pb(56.16%)" data-reactid="37" tabindex="-1">
#                          <img alt="What sets Apple Card apart from most other cards" class=" W(100%) Trs(streamHeroImgFilterTrans) streamHeroImage:h_Op(0.9) streamHeroImage:h_Fil(ntkImgFilterHover) Fil(streamHeroImgFilter)" data-reactid="38" src="https://s.yimg.com/uu/api/res/1.2/EdnLRBCQIk0rObIyZreXbQ--~B/Zmk9c3RyaW07aD0xMTY7cHlvZmY9MDtxPTk1O3c9MjA2O3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media-mbst-pub-ue1.s3.amazonaws.com/creatr-uploaded-images/2019-08/a1f0cb40-c9ca-11e9-adf0-b004de5523ee"/>
#                         </div>
#                         <div class="Pos(a) B(0) Start(0) End(0) Pt(20px) Bg(streamHeroGradient)" data-reactid="39">
#                          <h3 class="Td(n) C(#fff) Fz(13px) Td(u):h LineClamp(3,45px) Mend(30px) Mend(23px)--md1100 Mstart(12px) B(0) Fw(b) Mb(10px) Lh(15px) Tsh(streamHeroTextShadow) Whs(n)" data-reactid="40">
#                           What sets Apple Card apart from most other cards
#                          </h3>
#                         </div>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li data-reactid="41">
#                   <div class="ad-lrec" data-reactid="42" style="background-color:#fff;text-align:center;padding-top:5px;">
#                    <div data-reactid="43">
#                     <div class="" data-reactid="44">
#                      <div class="darla-container lrec-ldrb-ad darla-nonlrec34-ad darla-nonlrec34ldrb-ad darla-lrec-ad" data-reactid="45" id="defaultLREC-sizer">
#                       <!-- react-text: 46 -->
#                       <!-- /react-text -->
#                       <div class="" data-reactid="47" id="defaultLREC-wrapper">
#                        <div id="defaultdestLREC" style="width:300px;height:250px;">
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="js-stream-content" data-reactid="48">
#                   <div class="Py(14px) Pos(r)" data-reactid="49" data-test-locator="mega">
#                    <div class="Cf" data-reactid="50">
#                     <div class="Fl(start) Pos(r) Mt(2px) W(30%) Maw(255px)" data-reactid="51">
#                      <div class="H(0) Ov(h) Bdrs(2px)" data-reactid="52" style="padding-bottom:88%;">
#                       <img alt="10 Best Dividend Stocks to Buy for the Rest of 2019 and Beyond" class=" W(100%) Trsdu(0s)! Bdrs(2px)" data-reactid="53" src="https://s.yimg.com/uu/api/res/1.2/rBqv6ydTxuiK3uaEsK9B_A--~B/Zmk9c3RyaW07aD0xOTM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/dc372e5bca2424ee3d68c5ca164f018a" srcset="https://s.yimg.com/uu/api/res/1.2/rBqv6ydTxuiK3uaEsK9B_A--~B/Zmk9c3RyaW07aD0xOTM7cHlvZmY9MDtxPTgwO3c9MjIwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/dc372e5bca2424ee3d68c5ca164f018a 1x,https://s.yimg.com/uu/api/res/1.2/wJ7.mBxGI4sCbEVoKZue7A--~B/Zmk9c3RyaW07aD0zODY7cHlvZmY9MDtxPTgwO3c9NDQwO3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-US/investorplace_417/dc372e5bca2424ee3d68c5ca164f018a 2x"/>
#                      </div>
#                     </div>
#                     <div class="Ov(h) Pstart(25px)" data-reactid="54">
#                      <div class="C(#959595) Fz(11px) D(ib) Mb(6px)" data-reactid="55">
#                       InvestorPlace
#                      </div>
#                      <h3 class="Mb(5px)" data-reactid="56">
#                       <a class="Fw(b) Fz(20px) Lh(23px) Fz(17px)--sm1024 Lh(19px)--sm1024 Td(n) C(#0078ff):h C(#000) LineClamp(2,46px) LineClamp(2,38px)--sm1024" data-reactid="57" href="/news/10-best-dividend-stocks-buy-190736824.html">
#                        <u class="StretchedBox" data-reactid="58">
#                        </u>
#                        <!-- react-text: 59 -->
#                        10 Best Dividend Stocks to Buy for the Rest of 2019 and Beyond
#                        <!-- /react-text -->
#                       </a>
#                      </h3>
#                      <p class="Fz(14px) Lh(19px) Fz(13px)--sm1024 Lh(17px)--sm1024 LineClamp(2,38px) LineClamp(2,34px)--sm1024 M(0) D(n)--sm1024 Bxz(bb) Pb(2px)" data-reactid="60">
#                       Tech Industry Dividend Stocks for Growth and Income These 10 stocks don't quite qualify as “set it and forget it” plays. All have some degree of risk. But the risks seem worth taking for the potential rewards, which include near-term income, longer-term growth, and potential capital appreciation.
#                      </p>
#                      <ul class="Cf Mt(12px) Fz(12px) Pos(r) Mt(8px)--sm1024" data-reactid="61">
#                       <li class="Fl(start) W(50%) W(100%)--sm1024 Mb(8px)--sm1024" data-reactid="62">
#                        <a class="Td(n) D(ib) Va(t) W(90%) Mend(10%) C(#0078ff)!:h C(#000) C(#959595):vi" data-reactid="63" href="/news/3-dividend-aristocrats-buy-hold-131300160.html">
#                         <img alt="3 Dividend Aristocrats to Buy and Hold Forever" class=" Fl(start) W(29%) Miw(65px) Maw(72px) Mend(10px) Trsdu(0s)! D(n)--sm1024 Bdrs(2px)" data-reactid="64" src="https://s.yimg.com/uu/api/res/1.2/.4lSSdWAx2PXTs862zLsZg--~B/Zmk9c3RyaW07aD0xNDQ7cHlvZmY9MDtxPTgwO3c9MTQ0O3NtPTE7YXBwaWQ9eXRhY2h5b24-/http://media.zenfs.com/en-US/homerun/motleyfool.com/f6e34492fda567f9108426e376e3c3e5"/>
#                         <div class="Ov(h)" data-reactid="65">
#                          <div class="Lh(15px) Fw(b) LineClamp(3,45px) D(i)--sm1024 Pend(10px)--sm1024" data-reactid="66">
#                           3 Dividend Aristocrats to Buy and Hold Forever
#                          </div>
#                          <div class="C(#959595) Fz(11px) Mt(2px) Va(b) D(ib)--sm1024" data-reactid="67">
#                           Motley Fool
#                          </div>
#                         </div>
#                        </a>
#                       </li>
#                       <li class="Fl(start) W(50%) W(100%)--sm1024" data-reactid="68">
#                        <a class="Td(n) D(ib) Va(t) W(90%) Mend(10%) C(#0078ff)!:h C(#000) C(#959595):vi" data-reactid="69" href="/news/5-dividend-growth-stocks-sale-124112322.html">
#                         <img alt="5 Dividend Growth Stocks on Sale" class=" Fl(start) W(29%) Miw(65px) Maw(72px) Mend(10px) Trsdu(0s)! D(n)--sm1024 Bdrs(2px)" data-reactid="70" src="https://s.yimg.com/uu/api/res/1.2/4I5JUqFwGGDcKjv0LcXg7w--~B/Zmk9c3RyaW07aD0xNDQ7cHlvZmY9MDtxPTgwO3c9MTQ0O3NtPTE7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en-us/zacks.com/c226a627c3d561d32b6a74c4dde65aea"/>
#                         <div class="Ov(h)" data-reactid="71">
#                          <div class="Lh(15px) Fw(b) LineClamp(3,45px) D(i)--sm1024 Pend(10px)--sm1024" data-reactid="72">
#                           5 Dividend Growth Stocks on Sale
#                          </div>
#                          <div class="C(#959595) Fz(11px) Mt(2px) Va(b) D(ib)--sm1024" data-reactid="73">
#                           Zacks
#                          </div>
#                         </div>
#                        </a>
#                       </li>
#                      </ul>
#                     </div>
#                    </div>
#                   </div>
#                  </li>
#                  <li class="js-stream-content" data-reactid="74">
#                   <div class="Cf Ov(h) Pos(r) Py(14px) Mt(-3px) controller" data-reactid="75">
# ...
# window.DARLA_CONFIG = {"debug":false,"dm":1,"autoRotation":10000,"rotationTimingDisabled":true,"k2":{"res":{"rate":5,"pos":["BTN","BTN-1","BTN-2","BTN-3","BTN1","LREC","LREC2","LREC3","LDRB","MAST"]}},"positions":{"DEFAULT":{"name":"DEFAULT","enable":true,"fallback":null,"metaSize":false,"staticLayout":false,"clean":"defaultcleanDEFAULT","dest":"defaultdestDEFAULT","id":"DEFAULT","meta":{"hostURL":"https://finance.yahoo.com/"}},"WPS":{"id":"WPS","clean":"defaultcleanWPS","dest":"defaultdestWPS","metaSize":true,"w":320,"h":50,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN1":{"id":"BTN1","clean":"defaultcleanBTN1","dest":"defaultdestBTN1","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN1-1":{"id":"BTN1","clean":"defaultcleanBTN1-1","dest":"defaultdestBTN1-1","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN":{"id":"BTN","clean":"defaultcleanBTN","dest":"defaultdestBTN","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-1":{"id":"BTN-1","clean":"defaultcleanBTN-1","dest":"defaultdestBTN-1","w":120,"h":60,"enable":false,"fallback":null,"metaSize":false,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-2":{"id":"BTN-2","clean":"defaultcleanBTN-2","dest":"defaultdestBTN-2","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-3":{"id":"BTN-3","clean":"defaultcleanBTN-3","dest":"defaultdestBTN-3","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-5":{"id":"BTN-5","clean":"defaultcleanBTN-5","dest":"defaultdestBTN-5","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-6":{"id":"BTN-6","clean":"defaultcleanBTN-6","dest":"defaultdestBTN-6","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-7":{"id":"BTN-7","clean":"defaultcleanBTN-7","dest":"defaultdestBTN-7","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTN-8":{"id":"BTN-8","clean":"defaultcleanBTN-8","dest":"defaultdestBTN-8","metaSize":true,"w":120,"h":60,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTNA":{"id":"BTNA","clean":"defaultcleanBTNA","dest":"defaultdestBTNA","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTNB":{"id":"BTNB","clean":"defaultcleanBTNB","dest":"defaultdestBTNB","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTNC":{"id":"BTNC","clean":"defaultcleanBTNC","dest":"defaultdestBTNC","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"BTND":{"id":"BTND","clean":"defaultcleanBTND","dest":"defaultdestBTND","metaSize":true,"w":120,"h":60,"enable":false,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"WIDGET":{"id":"WIDGET","clean":"defaultcleanWIDGET","dest":"defaultdestWIDGET","metaSize":false,"w":650,"h":635,"enable":true,"fallback":null,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"FOOT":{"id":"FOOT","clean":"defaultcleanFOOT","dest":"defaultdestFOOT","fr":"expIfr_exp","failed":true,"enable":true,"fallback":null,"metaSize":false,"staticLayout":false,"meta":{"hostURL":"https://finance.yahoo.com/"}},"FSRVY":{"id":"FSRVY","clean":"defaultcleanFSRVY" ...
# window.DARLA_CONFIG.servicePath = window.location.protocol + "//fc.yahoo.com/sdarla/php/fc.php";window.DARLA_CONFIG.dm = 1;window.DARLA_CONFIG.onStartRequest = function() {window._perfMark('DARLA_REQSTART');};
# window.DARLA_CONFIG.onFinishRequest = function() {window._perfMark('DARLA_REQEND');};
# window.DARLA_CONFIG.onStartParse = function() {window._perfMark('DARLA_PSTART');};
# window.DARLA_CONFIG.onSuccess = function(eventName) {if (eventName === 'AUTO') {return;}if (window._DarlaEvents) {window._DarlaEvents.emit("success", {eventName: eventName});}window._perfMark('DARLA_DONE_' + eventName);window._darlaSuccessEvt = eventName;if (window._loadEvt) {window._fireAdPerfBeacon(eventName);}};
# window.DARLA_CONFIG.onStartPosRender = function(posItem) {var posId = posItem && posItem.pos;window._perfMark('DARLA_ADSTART_' + posId);if (window._pushAdPerfMetric) {window._pushAdPerfMetric("DARLA_ADSTART_" + posId);}};
# window.DARLA_CONFIG.onFinishPosRender = function(posId, reqList, posItem) {var ltime;window._perfMark('DARLA_ADEND_' + posId);window._perfMeasure('DARLA_RENDERTIME_' + posId, 'DARLA_ADSTART_'+posId, 'DARLA_ADEND_'+posId);if(window._DarlaEvents) {window._DarlaEvents.emit("finishrender", {pos:posId, list:reqList, item:posItem});}var aboveFoldPositions = ["WPS","MAST","LDRB","SPRZ","SPL","LREC","BTN","BTN-1","BTN-2","BTN-3","BTN1","BTNA","BTNB","BTNC","BTND","FB2","FB2-1","FB2-2","FB2-3","FB2A","FB2B","FB2C","FB2D","NE4","NE4-1","NE4-2","NE4-3","NE4A","NE4B","NE4C","NE4D"];if (window._pushAdPerfMetric) {if (window.performance && window.performance.now) {ltime = window.performance.now();}window._pushAdPerfMetric("ADEND_"+posId);var adModDiv = posItem.conf.dest.replace("dest", "") + "-sizer";setTimeout(function () {if (window.performance && window.YAFT !== undefined &&window.YAFT.isInitialized() && -1 !== aboveFoldPositions.indexOf(posId)) {window.YAFT.triggerCustomTiming(adModDiv, "", ltime);}}, 300);}};
# window.DARLA_CONFIG.onBeforePosMsg = function(msg, posId) {var maxWidth = 970, maxHeight = 600;var newWidth, newHeight, pos;if ("MAST" !== posId) {return;}if (msg === "resize-to") {newWidth = arguments[2];newHeight = arguments[3];} else if (msg === "exp-push" || msg === "exp-ovr") {pos = $sf.host.get("MAST");newWidth = pos.conf.w + arguments[6] + arguments[7];newHeight = pos.conf.h + arguments[5] + arguments[8];}if (newWidth > maxWidth || newHeight > maxHeight) {return true;}};
# window.DARLA_CONFIG.onFinishParse = function(eventName, response) {try {window._perfMark('DARLA_PEND');if (eventName === "prefetch") {window._DarlaPrefetchResponse = response;}if (window._DarlaEvents) {window._DarlaEvents.emit("finishparse", {response: response,eventName: eventName});}} catch (e) {console.error(e);throw e;}
# };
# window.DARLA_CONFIG.onStartPrefetchRequest = function(eventName) {window._perfMark('DARLA_PFSTART');};
# window.DARLA_CONFIG.onFinishPrefetchRequest = function(eventName, status) {window._perfMark('DARLA_PFEND');try {window._DarlaEvents.emit('finishprefetch', {status: status,eventName: eventName});} catch (e) {console.error(e);throw e;}
# };
# window.DARLA_CONFIG.onPosMsg = function(cmd, pos, msg) {try {if (window._DarlaEvents && cmd === "cmsg") {var posmsg = {pos: pos,msg: msg};window._DarlaEvents.emit("splashmsg", posmsg);if (window._adPosMsg) {window._adPosMsg[window._adPosMsg.length] = posmsg;}}if (window._DarlaEvents && (cmd === "ui-fclose-show" || cmd === "ui-fclose-close")) {setTimeout(function _emitAdResize(){window._DarlaEvents.emit("adresize", {pos: pos})}, 0);}} catch (e) {console.error(e);throw e;}
# };
# (function () {var _onloadEvt = function _onloadEvtHandler() {window._loadEvt = true;if (window._darlaSuccessEvt) {window._fireAdPerfBeacon(window._darlaSuccessEvt);}};if (window.addEventListener) {window.addEventListener("load", _onloadEvt);} else if (window.attachEvent) {window.attachEvent("onload", _onloadEvt);}function _onDarlaError (type) {return function _darlaErrHandler(evName) {try {if (window._DarlaEvents) {window._DarlaEvents.emit("darlaerror" + evName);window._DarlaEvents.emit("darlaerror", {type: type,eventName: evName,error: true});}} catch (e) {console.error(e);throw e;}};};window.DARLA_CONFIG.onRequestTimeout = _onDarlaError("requestTimeout");window.DARLA_CONFIG.onRenderTimeout = _onDarlaError("renderTimeout");window.DARLA_CONFIG.onFailure = _onDarlaError("failure");window.DARLA_CONFIG.onIdle = function onDarlaIdle () {    try {        window._DarlaEvents && window._DarlaEvents.emit("onIdle");    } catch (e) {        console.error(e);        throw e;    }};})();
# window.$sf = window.sf = {};
# window.$sf.host = {onReady: function (autorender, deferrender, firstRenderPos, deferRenderDelay) {window._perfMark('DARLA_ONREADY');window._perfMeasure('DARLA_ONREADY');window.sfready = true;if (window._DarlaEvents && !autorender) {window._DarlaEvents.emit("darlaboot");} else if (autorender){window._perfMark('DARLA_RSTART');if (typeof DARLA !== "undefined" && DARLA) {if (deferrender && firstRenderPos) {var firstBatchPos = [];var prefetchedPos = DARLA.prefetched();if (prefetchedPos.length <= 0) {return;}var firstRender = firstRenderPos.split(',');if (firstRender && firstRender.length > 0) {for (var i = 0; i < firstRender.length; i++) {var position = firstRender[i];var index = prefetchedPos.indexOf(position);if (index >= 0) {firstBatchPos = firstBatchPos.concat(prefetchedPos.splice(index, 1));}};}if (firstBatchPos.length > 0) {var renderWithRetry = function(pos) {if (DARLA.inProgress()) {var waittime = 600, maxwait = 100, deferRetry = 0, interval;interval = setInterval(function() {deferRetry ++;if (!DARLA.inProgress()){clearInterval(interval);DARLA.render(pos);}if (deferRetry > maxwait){clearInterval(interval);}}, waittime);} else {DARLA.render(pos);}};renderWithRetry(firstBatchPos);setTimeout(renderWithRetry, deferRenderDelay, prefetchedPos);} else {DARLA.render();}} else {DARLA.render();}}}}
# };
# window.sf_host = window.$sf.host;
# document.onreadystatechange = function () {if (document.readyState == "interactive") {window._perfMark('DOM_INTERACTIVE');}};
#    </script>
#    <script _ver="3-16-1" id="fc" type="text/x-safeframe">
#     {"positions":[{"id":"LREC","html":"<script type='text\/javascript'>var adContent = '';\nadContent += '<!-- AdPlacement : y402781 --><!-- Oath SSP BannerAd DspId:5357, SeatId:951609, DspCrId:1740468 --><!-- Ad Feedback Markup v1 -->' + '\\n';\nadContent += '                  <scr' + 'ipt id=\"yax_meta\" type=\"text\/x-yax-meta\">' + '\\n';\nadContent += '                    {' + '\\n';\nadContent += '                      \"fdb_url\": \"https:\/\/beap-bc.yahoo.com\/af\/us?bv=1.0.0&bs=(15kph0v6n(gid$FtVfhjk4LjEE3NehXWbhZwEYMTk5LgAAAAAU6GJi-0,st$1567023463732000,li$11064,cr$1740468,dmn$duracell.com,srv$4,exp$1567028263732000,ct$26,v$1.0,adv$11064,pbid$52469,seid$179355051))&al=(type${type},cmnt${cmnt},subo${subo})&r=66914\",' + '\\n';\nadContent += '                      \"fdb_on\": 1,' + '\\n';\nadContent += '                      \"fdb_exp\": 1567028263732,' + '\\n';\nadContent += '                      \"fdb_intl\": \"en-US\",' + '\\n';\nadContent += '                      \"err\": \"\"' + '\\n';\nadContent += '                    }' + '\\n';\nadContent += '                  <\/scr' + 'ipt>' + '\\n';\nadContent += '                  <scr' + 'ipt type=\"text\/javascript\">' + '\\n';\nadContent += '                    (function() {' + '\\n';\nadContent += '                      var w = window,' + '\\n';\nadContent += '                        sf = (w && w.$sf && w.$sf.ext),' + '\\n';\nadContent += '                        di = document.getElementById(\"yax_meta\");' + '\\n';\nadContent += '' + '\\n';\nadContent += '                      if (sf && typeof sf.msg == \"function\" && di) {' + '\\n';\nadContent += '                        sf.msg({cmd:\"fdb\", data: di});' + '\\n';\nadContent += '                      }' + '\\n';\nadContent += '                    })();' + '\\n';\nadContent += '                  <\/scr' + 'ipt><i' + 'mg src=\"https:\/\/us-west-1.onemobile.yahoo.com\/admax\/adEvent.do?tidi=770771327&amp;sitepid=217491&amp;posi=770108&amp;grp=%3F%3F%3F&amp;nl=1567023463952&amp;rts=1567023463732&amp;pix=1&amp;et=1&amp;a=FtVfhjk4LjEE3NehXWbhZwEYMTk5LgAAAAAU6GJi-0&amp;m=aXAtMTAtMjItNDUtNjI.&amp;p=MC4wMDAyNg&amp;b=MTEwNjQ7OTUxNjA5O2R1cmFjZWxsLmNvbTs7OzswMWQ4NzU4OGEyM2E0MmY5OTdiZTY2NmM0MmI2ZGYzNDsxNTE5NTM7MTU2NzAyMDYwMA..&amp;xdi=Pz8_fD8_P3w_Pz98MA..&amp;xoi=MHxVU0E.&amp;hb=true&amp;type=5&amp;brxdPublisherId=20459933223&amp;brxdSiteId=4902551&amp;brxdSectionId=179355051&amp;dety=2\" style=\"display:none;width:1px;height:1px;border:0;\" width=\"1\" height=\"1\" alt=\"\"\/><scr' + 'ipt type=\"text\/javascript\" src=\"https:\/\/pr.ybp.yahoo.com\/ab\/secure\/true\/imp\/H9kFTVdRaEZ2L_Iesi_MRSDVXa8d-C0mBJrikt29liuYsRC2X1uzdSFwMrzBIgyhaFVvgRgpphAX89ZulbAoa7ys5SD7nqcUoU_ZT5_DwtS2_8RqFUyPTuOVKS2BPu6hH34Zif4qNOn1R077rsLHAaVMm-dJjsMz344Tvqgk4FBpwAECjpX2s5Fpd4awEhY1uI1VlVJgUWKqUb_-aLFoXZp_xG8l3vYjn3HqtC7vbOyWEwPt9UWlIriwoyQP_2Sxs5A6hsC1ZQ2VqBNFflaC7fxUkRcvEldVdiru6BcTQbi_3xatnDgVTOwQxj4fenTkCm9uNLVmjHneZqCFcAl29f1NoavAcOANY7iYv-prsHD0cHxURnp1CGxZz5pZaCSQgNmNEhytWo0oc6JUgNGbV9AwxzEQvYTTqU2YMg35nOmHo7vJceijounPAN9Z5QbH62ABPwp9q7otYB6bL3wdFybAWNPCoRm4cp71wStnXmUMyLA7gLuZM3ITjU0bLQeMdvoio1PyhxOY-OSgyUOGUlY6im67SkyinrgnR5pdVK-PfEeuSdZbwgOkOf7dSv5FhVMThv0ZUeDQzkmfTp8HG-3LZ9lJaoUmIrt3MmqMzWarqqLmwiYY-Uzx3LLqnG55_ZVhLWbNoE2J5lApVpQmWloKOrWtHFj3gLOKtkVtuOF38hUV9pnXs7yXmKfZO4nxa6aKIHevphZF7n7RxH7tS3DySMxvtB1OkaaFrbhYytlG3_NBf4i3h8MKevVg12CsT1MWsZq1inPKrTbtPo_pzIfWCX41H197elXl8feUktxXsT-fclqeruDZ364Un2TrSzq9eITHZTmJpvL8KksEHBFzaNs23ulTDyV6xZ5HQXun8i90p0dpSHxvTb-ijS3MCpx5YRyczAxK2P5LtngLm4IwoffO-z1avAox-XL6CgyZCvyucreAlQUxmE4LwKGQ90QGemNpin4Q9AToK8_6mSIfT31xtfwK_DiBO3qGqcECC5rnbGdjREh8pJnHYKWwYywvn0PKKDFertiavrclPnOYAoNpuCpHMybHzzXVGnWxxFvppC-JjDfTyTKSMgGTdHGkNMLRQkzDZ_jpacoDOLumCP1ezYXTQZCxWBJMToCGMhH0ZfNFsU6fJqlUPofmB9illVGYbmUvVNGLsyvogAE3Ha0ke13E_4DuRAK-JoHTaT6qIGgk9mapbO6l71uUrIsnIDV4u9YLndW6sknFja5shlXPYlc3XGVKEkzherCfnjWkLFawlhi3DjkSi0bEezs3r_Wv_x2uhXXGPwfvzJUwEltB04no-8S_KHXhe98gVxe8VOlqliBoR4tv-B8PavjytWx-aYEztfFr9YUo7dY-tci8fiKgs8yZ0xw ...
#    </script>
#    <meta content="..." itemprop="metadata/x-safeframe"/>
#    <!-- gq1-sdarlaws-004.adx.gq1.yahoo.com Wed Aug 28 20:17:43 UTC 2019 -->
#    <script type="text/javascript">
#     if (typeof DARLA !== "undefined" && DARLA) {DARLA.config(window.DARLA_CONFIG);window.sf_host.onReady(true,true,'BTNA,BTNB,BTNC,BTND,LDRB,LREC,MAST,SCREC',3000);}
#    </script>
#    <style>
#     .hide-lrec-ad .darla-lrec-ad {display: none;}.hide-non-lrec34 .darla-nonlrec34-ad {display: none;}.hide-non-lrec34 .sticky-outer-wrapper .tdv2-applet-stream .js-stream-content .controller,.hide-non-lrec34 .YDC-Height-Container .tdv2-applet-stream .js-stream-content .controller {display: none;}.hide-non-lrec34ldrb .darla-nonlrec34ldrb-ad {display: none;}.hide-non-lrec34ldrb .sticky-outer-wrapper .tdv2-applet-stream .js-stream-content .controller,.hide-non-lrec34ldrb .YDC-Height-Container .tdv2-applet-stream .js-stream-content .controller {display: none;}.hide-lrec-groups-lrec12 .darla-nonlrec34ldrb-ad,.hide-lrec-groups-lrec34 .darla-lrec34-ad,.hide-all-lrecs .darla-lrec-ad {display: none;}
#    </style>
#   </div>
#   <script>
#    window.daggr=window.daggr||{};window.daggr.results={};window.daggr.results['StreamService:slingstoneStream-0-Stream']=null
# ;window.daggr.fallbackData=[{requesters: [{id:"slingstoneStream-0-Stream", dataKey:"streamItems"}], result: window.daggr.results['StreamService:slingstoneStream-0-Stream']}];
#   </script>
#   <script defer="" src="https://s.yimg.com/zz/combo?uc/finance/dd-site/js/main-lightweight.a907ecd015c337b25fbd.lightweight.js&amp;os/yaft/yaft-0.3.27.min.js&amp;os/yaft/yaft-plugin-aftnoad-0.1.5.min.js">
#   </script>
#   <script>
#    window.webpackPublicPath='https://s.yimg.com/uc/finance/dd-site/js/';
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## Finding all the news headlines and  news sources

# %%
news = soup.find_all("h3", class_="Mb(5px)")
print "Number of news: %d\n" % (len(news))
titles = []
sources = []
for element in news:
    t = element.a
    titles.append(t.get_text())
    s = t['href']
    sources.append(s)
    print t.get_text()
    print data_source + s
# Out:
# Number of news: 25
#
# 10 Best Dividend Stocks to Buy for the Rest of 2019 and Beyond
# https://finance.yahoo.com//news/10-best-dividend-stocks-buy-190736824.html
# There’s a ‘bubble’ in passive investing, says investor made famous by ‘Big Short’
# https://finance.yahoo.com//m/8a50c9db-2153-3569-821b-11680fd5bc96/there%E2%80%99s-a-%E2%80%98bubble%E2%80%99-in-passive.html
# De Beers hits a rough patch as diamond sales slide
# https://finance.yahoo.com//m/eee8fcab-d054-3de4-b418-3f14b63f5175/de-beers-hits-a-rough-patch.html
# Trump's China Trade War Disrupts U.S. Mortgage Refinancing Boom
# https://finance.yahoo.com//m/68fbfd56-fca5-359d-ab60-d1c66f8c309e/trump%27s-china-trade-war.html
# 8 Types of Americans Who Aren't Eligible to Get Social Security
# https://finance.yahoo.com//m/cb65aeb9-3006-3c83-b0f2-6d9330ee6c18/8-types-of-americans-who.html
# More cruise companies sued over business dealings in Cuba
# https://finance.yahoo.com//m/01ddada5-7313-3cf6-8f49-6f6169f1aa99/more-cruise-companies-sued.html
# Analysts Turn Incrementally Bullish After Veeva's Beat And Raise
# https://finance.yahoo.com//news/analysts-turn-incrementally-bullish-veevas-165506837.html
# Pension Funds Reel From Falling Bond Yields
# https://finance.yahoo.com//video/pension-funds-reel-falling-bond-190943934.html
# A High Yield Bond Fund that Changes with the Times
# https://finance.yahoo.com//news/high-yield-bond-fund-changes-100000823.html
# Income Expert Takes a Ride with Ford
# https://finance.yahoo.com//news/income-expert-takes-ride-ford-100000576.html
# The biggest differences between Apple's new credit card and most other cards
# https://finance.yahoo.com//news/apple-card-review-195106544.html
# Gold Flirts With 1,550, Where Is Gold’s Top? Silver at 18.50
# https://finance.yahoo.com//news/gold-flirts-1-550-where-130321456.html
# Why General Electric Stock Is Ruled By Fear Yet Again
# https://finance.yahoo.com//news/why-general-electric-stock-ruled-135654081.html
# [video]Tesla Launches Auto Insurance Offering
# https://finance.yahoo.com//m/82d031b1-d211-343e-b2a3-509a29f3952d/%5Bvideo%5Dtesla-launches-auto.html
# Tesla launches its car insurance in California
# https://finance.yahoo.com//m/687e94ef-8842-3d01-a367-75f5b6453251/tesla-launches-its-car.html
# The 3 Big Reasons to Stick With BABA Stock During This Chop
# https://finance.yahoo.com//news/3-big-reasons-stick-baba-135221564.html
# Blackstone Offers to Take Tallgrass Private as Shares Plunge 40%
# https://finance.yahoo.com//video/blackstone-offers-tallgrass-private-shares-162703177.html
# EMERGING MARKETS-Latam currencies weaken over growth worries, stocks rise
# https://finance.yahoo.com//news/emerging-markets-latam-currencies-weaken-195758327.html
# Goldman Sachs: 5 ‘Strong Buy’ Stocks To Beat Market Volatility
# https://finance.yahoo.com//news/goldman-sachs-5-strong-buy-145029866.html
# Miami-based Popeyes is completely out of chicken sandwiches
# https://finance.yahoo.com//m/fcebae27-1dc1-363a-b6d7-88fcc0df0313/miami-based-popeyes-is.html
# Salesforce Stock Is a Great Market Barometer
# https://finance.yahoo.com//news/salesforce-stock-great-market-barometer-130253518.html
# Citi Adopts $15 Minimum Wage After Prod From Maxine Waters
# https://finance.yahoo.com//news/citi-adopts-15-minimum-wage-231346845.html
# Tesla Is Getting Into the Car Insurance Business
# https://finance.yahoo.com//m/229c50e3-5363-36f3-bda0-cd6953c1fddf/tesla-is-getting-into-the-car.html
# Apple's data shows a deepening dependence on China as Trump's tariffs loom
# https://finance.yahoo.com//news/apples-data-shows-deepening-dependence-181324866.html
# AMD Settles For $12.1M In False Advertising Lawsuit
# https://finance.yahoo.com//news/amd-settles-12-1m-false-161749235.html

# %%
 
with open("headlines.csv", 'wb') as file:
    writer = csv.writer(file, delimiter=',')
    for t, s in zip(titles, sources):
        writer.writerow([t.encode('utf-8').strip(), s])

# %% [markdown]
# ## Getting world market data from Yahoo Finance

# %%
#different url here
data_source = 'https://finance.yahoo.com/world-indices'
req = urllib2.Request(data_source, headers={'User-Agent': 'Mozilla/5.0'})
page = urllib2.urlopen(req).read()
soup= BeautifulSoup(page, "html5lib")
markets = soup.find("div", class_="Ovx(a)")

#print markets.prettify()

# %%
symbols = {}
rows = markets.find_all('li')

for row in rows:
    
    symbol = row.find_all('a')
    price = row.find_all('span', class_="Trsdu(0.3s) Fz(s) Mb(0px) D(b)")
    change = row.find_all('span', class_="Trsdu(0.3s) Fz(s) D(b) C($dataGreen)")
    
    if not change:
        change = row.find_all('span', class_="Trsdu(0.3s) Fz(s) D(b) C($dataRed)")
    if not (symbol):
        continue
        
    url = data_source + symbol[0].get('href')
    name = symbol[0].get('title')
    val = price[0].get_text().strip()
    chng = change[0].get_text().strip().split()
    symbols[name] = [url, val, chng[0]]
    print name, symbols[name]
# Out:
# S&P 500 [u'https://finance.yahoo.com/world-indices/quote/^GSPC?p=^GSPC', u'2,887.94', u'+0.65%']
# Dow 30 [u'https://finance.yahoo.com/world-indices/quote/^DJI?p=^DJI', u'26,036.10', u'+1.00%']
# Nasdaq [u'https://finance.yahoo.com/world-indices/quote/^IXIC?p=^IXIC', u'7,856.88', u'+0.38%']
# Russell 2000 [u'https://finance.yahoo.com/world-indices/quote/^RUT?p=^RUT', u'1,472.70', u'+1.14%']
# Crude Oil [u'https://finance.yahoo.com/world-indices/quote/CL=F?p=CL=F', u'55.91', u'+1.78%']
# Gold [u'https://finance.yahoo.com/world-indices/quote/GC=F?p=GC=F', u'1,548.30', u'-0.23%']
# Silver [u'https://finance.yahoo.com/world-indices/quote/SI=F?p=SI=F', u'18.31', u'+0.86%']
# EUR/USD [u'https://finance.yahoo.com/world-indices/quote/EURUSD=X?p=EURUSD=X', u'1.1080', u'-0.1330%']
# 10-Yr Bond [u'https://finance.yahoo.com/world-indices/quote/^TNX?p=^TNX', u'1.4660', u'-1.61%']
# Vix [u'https://finance.yahoo.com/world-indices/quote/^VIX?p=^VIX', u'19.25', u'-5.22%']
# GBP/USD [u'https://finance.yahoo.com/world-indices/quote/GBPUSD=X?p=GBPUSD=X', u'1.2213', u'-0.6180%']
# USD/JPY [u'https://finance.yahoo.com/world-indices/quote/JPY=X?p=JPY=X', u'106.1700', u'+0.3972%']
# BTC-USD [u'https://finance.yahoo.com/world-indices/quote/BTC-USD?p=BTC-USD', u'9,681.10', u'-4.86%']
# FTSE 100 [u'https://finance.yahoo.com/world-indices/quote/^FTSE?p=^FTSE', u'7,114.71', u'+0.35%']
# Nikkei 225 [u'https://finance.yahoo.com/world-indices/quote/^N225?p=^N225', u'20,479.42', u'+0.11%']

# %%
with open("markets.csv", 'wb') as file:
    writer = csv.writer(file, delimiter=';')
    for name, vals in symbols.items():
        line = [name]
        line.extend(vals)
        print line
        writer.writerow(line)
# Out:
# [u'Crude Oil', u'https://finance.yahoo.com/world-indices/quote/CL=F?p=CL=F', u'55.91', u'+1.78%']
# [u'Dow 30', u'https://finance.yahoo.com/world-indices/quote/^DJI?p=^DJI', u'26,036.10', u'+1.00%']
# [u'Gold', u'https://finance.yahoo.com/world-indices/quote/GC=F?p=GC=F', u'1,548.30', u'-0.23%']
# [u'S&P 500', u'https://finance.yahoo.com/world-indices/quote/^GSPC?p=^GSPC', u'2,887.94', u'+0.65%']
# [u'FTSE 100', u'https://finance.yahoo.com/world-indices/quote/^FTSE?p=^FTSE', u'7,114.71', u'+0.35%']
# [u'BTC-USD', u'https://finance.yahoo.com/world-indices/quote/BTC-USD?p=BTC-USD', u'9,681.10', u'-4.86%']
# [u'USD/JPY', u'https://finance.yahoo.com/world-indices/quote/JPY=X?p=JPY=X', u'106.1700', u'+0.3972%']
# [u'Nasdaq', u'https://finance.yahoo.com/world-indices/quote/^IXIC?p=^IXIC', u'7,856.88', u'+0.38%']
# [u'10-Yr Bond', u'https://finance.yahoo.com/world-indices/quote/^TNX?p=^TNX', u'1.4660', u'-1.61%']
# [u'GBP/USD', u'https://finance.yahoo.com/world-indices/quote/GBPUSD=X?p=GBPUSD=X', u'1.2213', u'-0.6180%']
# [u'Nikkei 225', u'https://finance.yahoo.com/world-indices/quote/^N225?p=^N225', u'20,479.42', u'+0.11%']
# [u'Vix', u'https://finance.yahoo.com/world-indices/quote/^VIX?p=^VIX', u'19.25', u'-5.22%']
# [u'Russell 2000', u'https://finance.yahoo.com/world-indices/quote/^RUT?p=^RUT', u'1,472.70', u'+1.14%']
# [u'Silver', u'https://finance.yahoo.com/world-indices/quote/SI=F?p=SI=F', u'18.31', u'+0.86%']
# [u'EUR/USD', u'https://finance.yahoo.com/world-indices/quote/EURUSD=X?p=EURUSD=X', u'1.1080', u'-0.1330%']

# %% [markdown]
# ## Historical data from Yahoo

# %%
data_source = 'https://finance.yahoo.com/quote/SNAP/history?period1=1535487600&period2=1567023600&interval=1d&filter=history&frequency=1d'
req = urllib2.Request(data_source, headers={'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
       'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8'})
page = urllib2.urlopen(req).read()
soup = BeautifulSoup(page, "html5lib")

snap = soup.find("table", class_="W(100%) M(0)")

snap_header = snap.find('thead')
headers = snap_header.find_all('th')

snap_body = snap.find('tbody')
rows = snap_body.find_all('tr')

with open("snap.csv", 'wb') as file:
    writer = csv.writer(file, delimiter=',')
    header = [h.get_text().strip().replace("*", "") for h in headers]
    print header  
    writer.writerow(header)
    for row in rows:
        line = row.get_text().strip().split()
        date_tag = row.find_all("td", class_="Py(10px) Ta(start) Pend(10px)")
        if date_tag:
            values_tag = row.find_all("td", class_="Py(10px) Pstart(10px)")
            line = [date_tag[0].get_text().strip().replace(",", "")] + [v.get_text().strip().replace(",", "") for v in values_tag]
            print line
            writer.writerow(line)
# Out:
# [u'Date', u'Open', u'High', u'Low', u'Close', u'Adj Close', u'Volume']
# [u'Aug 28 2019', u'15.30', u'15.70', u'15.25', u'15.55', u'15.55', u'17186099']
# [u'Aug 27 2019', u'16.21', u'16.31', u'15.03', u'15.51', u'15.51', u'31412800']
# [u'Aug 26 2019', u'15.64', u'16.21', u'15.57', u'16.11', u'16.11', u'23633900']
# [u'Aug 23 2019', u'15.95', u'16.07', u'15.52', u'15.55', u'15.55', u'19909300']
# [u'Aug 22 2019', u'16.25', u'16.74', u'16.02', u'16.08', u'16.08', u'25025500']
# [u'Aug 21 2019', u'16.30', u'16.34', u'15.97', u'16.14', u'16.14', u'15796200']
# [u'Aug 20 2019', u'15.99', u'16.44', u'15.95', u'16.08', u'16.08', u'17829500']
# [u'Aug 19 2019', u'16.07', u'16.20', u'15.85', u'16.16', u'16.16', u'18707500']
# [u'Aug 16 2019', u'16.13', u'16.19', u'15.47', u'15.98', u'15.98', u'25843900']
# [u'Aug 15 2019', u'16.46', u'16.50', u'15.85', u'15.99', u'15.99', u'18200000']
# [u'Aug 14 2019', u'16.62', u'16.89', u'16.29', u'16.36', u'16.36', u'18094900']
# [u'Aug 13 2019', u'16.80', u'17.11', u'16.65', u'17.00', u'17.00', u'22329000']
# [u'Aug 12 2019', u'16.85', u'16.97', u'16.36', u'16.81', u'16.81', u'18098700']
# [u'Aug 09 2019', u'16.88', u'17.19', u'16.63', u'16.98', u'16.98', u'27503300']
# [u'Aug 08 2019', u'16.10', u'16.82', u'15.90', u'16.76', u'16.76', u'35592700']
# [u'Aug 07 2019', u'15.61', u'16.08', u'15.52', u'15.91', u'15.91', u'42074900']
# [u'Aug 06 2019', u'16.20', u'16.63', u'16.16', u'16.29', u'16.29', u'30305900']
# [u'Aug 05 2019', u'16.57', u'16.63', u'16.03', u'16.46', u'16.46', u'26598600']
# [u'Aug 02 2019', u'16.54', u'17.23', u'16.46', u'17.03', u'17.03', u'23809400']
# [u'Aug 01 2019', u'16.83', u'17.45', u'16.59', u'16.68', u'16.68', u'35265400']
# [u'Jul 31 2019', u'16.98', u'17.32', u'16.48', u'16.80', u'16.80', u'30566800']
# [u'Jul 30 2019', u'17.23', u'17.33', u'16.90', u'16.93', u'16.93', u'33597200']
# [u'Jul 29 2019', u'18.01', u'18.12', u'17.44', u'17.50', u'17.50', u'25542300']
# [u'Jul 26 2019', u'17.70', u'18.36', u'17.62', u'17.89', u'17.89', u'55913100']
# [u'Jul 25 2019', u'17.23', u'18.00', u'17.12', u'17.69', u'17.69', u'88040500']
# [u'Jul 24 2019', u'16.22', u'17.61', u'16.08', u'17.61', u'17.61', u'143867600']
# [u'Jul 23 2019', u'14.66', u'14.93', u'14.25', u'14.83', u'14.83', u'78779000']
# [u'Jul 22 2019', u'14.02', u'14.47', u'13.98', u'14.15', u'14.15', u'26770000']
# [u'Jul 19 2019', u'14.62', u'14.65', u'13.96', u'14.02', u'14.02', u'30424400']
# [u'Jul 18 2019', u'14.72', u'14.94', u'14.43', u'14.55', u'14.55', u'19050800']
# [u'Jul 17 2019', u'14.90', u'15.14', u'14.56', u'14.93', u'14.93', u'13471300']
# [u'Jul 16 2019', u'15.50', u'15.53', u'14.89', u'15.00', u'15.00', u'24523000']
# [u'Jul 15 2019', u'15.59', u'15.73', u'15.28', u'15.50', u'15.50', u'16919600']
# [u'Jul 12 2019', u'16.16', u'16.24', u'15.53', u'15.61', u'15.61', u'39198800']
# [u'Jul 11 2019', u'15.61', u'15.94', u'15.39', u'15.57', u'15.57', u'26709600']
# [u'Jul 10 2019', u'15.26', u'15.36', u'14.97', u'15.26', u'15.26', u'17194500']
# [u'Jul 09 2019', u'15.30', u'15.57', u'14.80', u'15.25', u'15.25', u'26250600']
# [u'Jul 08 2019', u'15.12', u'15.36', u'15.01', u'15.14', u'15.14', u'14292900']
# [u'Jul 05 2019', u'14.66', u'15.29', u'14.55', u'15.23', u'15.23', u'26456100']
# [u'Jul 03 2019', u'14.10', u'14.77', u'14.08', u'14.76', u'14.76', u'15065200']
# [u'Jul 02 2019', u'14.46', u'14.48', u'13.98', u'14.10', u'14.10', u'17823900']
# [u'Jul 01 2019', u'14.73', u'14.81', u'14.34', u'14.35', u'14.35', u'18527800']
# [u'Jun 28 2019', u'14.76', u'14.78', u'14.18', u'14.30', u'14.30', u'20060100']
# [u'Jun 27 2019', u'14.76', u'14.81', u'14.56', u'14.58', u'14.58', u'13185000']
# [u'Jun 26 2019', u'14.75', u'14.93', u'14.64', u'14.71', u'14.71', u'18330800']
# [u'Jun 25 2019', u'14.69', u'15.00', u'14.28', u'14.53', u'14.53', u'25174500']
# [u'Jun 24 2019', u'14.68', u'15.01', u'14.64', u'14.76', u'14.76', u'27563100']
# [u'Jun 21 2019', u'14.79', u'14.82', u'14.53', u'14.56', u'14.56', u'13530800']
# [u'Jun 20 2019', u'14.83', u'15.00', u'14.63', u'14.84', u'14.84', u'18754000']
# [u'Jun 19 2019', u'14.85', u'14.85', u'14.46', u'14.67', u'14.67', u'26536700']
# [u'Jun 18 2019', u'14.14', u'14.98', u'14.12', u'14.86', u'14.86', u'56473200']
# [u'Jun 17 2019', u'14.17', u'14.18', u'13.40', u'13.55', u'13.55', u'26879800']
# [u'Jun 14 2019', u'14.15', u'14.15', u'13.65', u'13.96', u'13.96', u'24189700']
# [u'Jun 13 2019', u'13.85', u'14.31', u'13.75', u'14.11', u'14.11', u'25003000']
# [u'Jun 12 2019', u'13.71', u'13.98', u'13.48', u'13.75', u'13.75', u'17515800']
# [u'Jun 11 2019', u'13.93', u'13.97', u'13.39', u'13.54', u'13.54', u'21898000']
# [u'Jun 10 2019', u'13.95', u'14.07', u'13.69', u'13.77', u'13.77', u'25589800']
# [u'Jun 07 2019', u'13.91', u'14.11', u'13.82', u'13.87', u'13.87', u'28549300']
# [u'Jun 06 2019', u'13.00', u'14.13', u'12.56', u'13.82', u'13.82', u'57526800']
# [u'Jun 05 2019', u'12.99', u'13.14', u'12.60', u'12.94', u'12.94', u'30010800']
# [u'Jun 04 2019', u'11.85', u'12.95', u'11.85', u'12.95', u'12.95', u'53352500']
# [u'Jun 03 2019', u'11.88', u'12.37', u'11.53', u'11.69', u'11.69', u'33333300']
# [u'May 31 2019', u'11.99', u'12.10', u'11.76', u'11.89', u'11.89', u'29254300']
# [u'May 30 2019', u'11.72', u'12.19', u'11.63', u'11.99', u'11.99', u'28744000']
# [u'May 29 2019', u'11.31', u'11.69', u'11.24', u'11.68', u'11.68', u'18806800']
# [u'May 28 2019', u'11.58', u'11.60', u'11.22', u'11.57', u'11.57', u'46617100']
# [u'May 24 2019', u'11.45', u'11.81', u'11.40', u'11.56', u'11.56', u'29187200']
# [u'May 23 2019', u'11.05', u'11.36', u'10.76', u'11.12', u'11.12', u'24490400']
# [u'May 22 2019', u'11.42', u'11.60', u'11.19', u'11.31', u'11.31', u'19407400']
# [u'May 21 2019', u'11.30', u'11.56', u'11.30', u'11.54', u'11.54', u'18344800']
# [u'May 20 2019', u'11.27', u'11.30', u'10.98', u'11.19', u'11.19', u'19753900']
# [u'May 17 2019', u'11.24', u'11.64', u'11.09', u'11.49', u'11.49', u'24817000']
# [u'May 16 2019', u'10.72', u'11.54', u'10.72', u'11.42', u'11.42', u'36343800']
# [u'May 15 2019', u'10.45', u'10.73', u'10.40', u'10.66', u'10.66', u'12390500']
# [u'May 14 2019', u'10.23', u'10.65', u'10.20', u'10.49', u'10.49', u'19956300']
# [u'May 13 2019', u'10.05', u'10.34', u'10.04', u'10.11', u'10.11', u'15911900']
# [u'May 10 2019', u'10.92', u'10.92', u'10.28', u'10.49', u'10.49', u'23159700']
# [u'May 09 2019', u'10.71', u'11.10', u'10.65', u'10.98', u'10.98', u'15840700']
# [u'May 08 2019', u'11.24', u'11.27', u'10.79', u'10.82', u'10.82', u'21362100']
# [u'May 07 2019', u'11.66', u'11.78', u'11.07', u'11.17', u'11.17', u'20793200']
# [u'May 06 2019', u'11.39', u'11.86', u'11.38', u'11.77', u'11.77', u'12552500']
# [u'May 03 2019', u'11.25', u'11.84', u'11.25', u'11.80', u'11.80', u'19211700']
# [u'May 02 2019', u'11.23', u'11.25', u'10.99', u'11.24', u'11.24', u'12005000']
# [u'May 01 2019', u'11.20', u'11.36', u'11.14', u'11.20', u'11.20', u'13583200']
# [u'Apr 30 2019', u'11.16', u'11.37', u'11.02', u'11.14', u'11.14', u'17017900']
# [u'Apr 29 2019', u'11.10', u'11.29', u'11.06', u'11.22', u'11.22', u'21473800']
# [u'Apr 26 2019', u'10.73', u'11.13', u'10.69', u'10.91', u'10.91', u'23725500']
# [u'Apr 25 2019', u'11.13', u'11.15', u'10.51', u'10.79', u'10.79', u'51272600']
# [u'Apr 24 2019', u'12.35', u'12.42', u'11.06', u'11.26', u'11.26', u'106430600']
# [u'Apr 23 2019', u'11.94', u'12.20', u'11.67', u'11.99', u'11.99', u'63113300']
# [u'Apr 22 2019', u'11.55', u'11.70', u'11.23', u'11.53', u'11.53', u'20725500']
# [u'Apr 18 2019', u'11.18', u'11.71', u'11.18', u'11.67', u'11.67', u'24285200']
# [u'Apr 17 2019', u'11.76', u'11.83', u'11.52', u'11.75', u'11.75', u'14681600']
# [u'Apr 16 2019', u'11.80', u'11.85', u'11.48', u'11.69', u'11.69', u'19741100']
# [u'Apr 15 2019', u'11.90', u'12.02', u'11.79', u'11.85', u'11.85', u'10578900']
# [u'Apr 12 2019', u'11.98', u'12.03', u'11.70', u'11.97', u'11.97', u'15400500']
# [u'Apr 11 2019', u'12.10', u'12.37', u'11.79', u'11.90', u'11.90', u'20186000']
# [u'Apr 10 2019', u'11.84', u'12.20', u'11.56', u'12.02', u'12.02', u'45526000']
# [u'Apr 09 2019', u'12.16', u'12.47', u'12.06', u'12.35', u'12.35', u'26261300']
# [u'Apr 08 2019', u'12.31', u'12.63', u'12.19', u'12.27', u'12.27', u'42413400']
